# %%
import pandas as pd

# %%
df1 = pd.read_csv('results/eff_15.csv')
df2 = pd.read_csv('results/eff_16.csv')
df3 = pd.read_csv('results/eff_17.csv')
df4 = pd.read_csv('results/eff_18.csv')
df5 = pd.read_csv('results/eff_19.csv')
df6 = pd.read_csv('results/eff_20.csv')

# %%
merged_efficiencies = pd.concat([df1,df2,df3,df4,df5,df6], ignore_index=True)

# %%
merged_efficiencies
# Out:
#                      Team Unnamed: 0 OVERALL OVERALL.1 OFFENSE OFFENSE.1  \
# 0       Carolina Panthers      W-L-T     EFF       RNK     EFF       RNK
# 1      Kansas City Chiefs     17-2-0    74.5         1    66.6         3
# 2       Arizona Cardinals     12-6-0    68.0         2    55.3        10
# 3    New England Patriots     14-4-0    67.5         3    72.5         1
# 4      Cincinnati Bengals     13-5-0    67.4         4    63.5         4
# ..                    ...        ...     ...       ...     ...       ...
# 193        Houston Texans      2-6-0    34.6        28    36.5        28
# 194        Dallas Cowboys      2-6-0    33.8        29    64.3        15
# 195  Jacksonville Jaguars      2-7-0    28.2        30    38.1        27
# 196         New York Jets      1-7-0    27.2        31    55.0        24
# 197                   NaN      0-9-0    16.4        32    27.5        32
#
#     DEFENSE DEFENSE.1 SPECIAL TEAMS SPECIAL TEAMS.1  Year
# ...

# %%
merged_efficiencies.to_csv('results/merged_efficiencies.csv')
