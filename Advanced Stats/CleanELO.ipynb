# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("538.csv", header=0)

# %%
df.head()
# Out:
#    ELO WITH QB  ELO CHANGE  CURRENT QB ADJ      TEAM   DIVISION PROJ WINS  \
# 0         1658         NaN             NaN    Chiefs   AFC West      11-5
# 1         1647         NaN             NaN    Ravens  AFC North      11-5
# 2         1614         NaN             NaN    Saints  NFC South      10-6
# 3         1601         NaN             NaN     49ers   NFC West      10-6
# 4         1573         NaN             NaN  Steelers  AFC North      10-6
#
#   PROJ LOSES POINT DIFF MAKE PLAYOFFS WIN DIVISION 1st-Round Bye  \
# 0        NaN     +113.6           86%          69%           25%
# 1        NaN     +106.7           82%          55%           24%
# 2        NaN      +75.0           72%          51%           17%
# 3        NaN      +66.8           68%          41%           15%
# 4        NaN      +57.0           65%          30%           10%
#
#   Win Superbowl  Before Week  Year
# 0           14%            1  2020
# 1           12%            1  2020
# 2            9%            1  2020
# 3            7%            1  2020
# 4            5%            1  2020

# %%
df = df.sort_values(["Year", "Before Week"])

# %%
def cleanWins(record):
    if("." in str(record)):
        return record
    elif (type(record) != float) and ("-" in record):
        regx = re.compile("\d+-")
        wins = regx.search(record)
        if wins != None:
            wins = wins[0][:-1]
        #losses = regx.search(record)[1]
            return wins

# %%
def cleanLs(record):
    if("." in str(record)):
        record = float(record)
        record = 16 - record
        return record
    elif (type(record) != float) and ("-" in record):
        regx = re.compile("-\d+")
        wins = regx.search(record)
        if wins != None:
            wins = wins[0][1:]
        #losses = regx.search(record)[1]
            return wins

# %%
df = df.assign(PROJ_WINS2 = lambda x: x["PROJ WINS"].apply(cleanWins))

# %%
df = df.assign(PROJ_LOSSES2 = lambda x: x["PROJ WINS"].apply(cleanLs))

# %%
df.shape
# Out:
# (3620, 16)

# %%
def realWins(name):
    regex = re.compile(".\d+-\d+")
    record = regex.search(name)
    if record != None:
        record = record[0]
        record = record[1:]
        rec = record.split("-")
        wins = rec[0]
        losses = rec[1]
        return wins
    else:
        return 0

# %%
df = df.assign(REAL_WINS = lambda x: x.TEAM.apply(realWins))

# %%
def realLss(name):
    regex = re.compile(".\d+-\d+")
    record = regex.search(name)
    if record != None:
        record = record[0]
        record = record[1:]
        rec = record.split("-")
        wins = rec[0]
        losses = rec[1]
        return losses
    else:
        return 0

# %%
df = df.assign(REAL_LOSSES = lambda x: x.TEAM.apply(realLss))

# %%
def cleanName(name):
    regex = re.compile("\d+-\d+")
    record = regex.search(name)
    if record != None:
        record = record[0]
        name = name.replace(record, "")
        return name
    else:
        return name

# %%
df = df.assign(CLEAN_NAME = lambda x: x.TEAM.apply(cleanName))

# %%
df = df.reset_index(drop=True)

# %%
df.to_csv("cleanerELO.csv")

# %%
df.assign(PROJ_WINS2 = lambda x: x["PROJ WINS"].apply(cleanWins))

# %%
type(12.3)
# Out:
# False

# %%
regx = re.compile("\d+-\d+")

# %%
regx.search("s2-2")
# Out:
# <re.Match object; span=(1, 4), match='2-2'>

# %%
sg = "12-3"

# %%
sg.split("-")
# Out:
# ['12', '3']

# %% [markdown]
# ### Final ELO

# %%
df_a = pd.read_csv("cleanerELO.csv", header=0, index_col=0)

# %%
df_a.head()
# Out:
#    ELO WITH QB  ELO CHANGE  CURRENT QB ADJ         TEAM   DIVISION PROJ WINS  \
# 0         1678         NaN             NaN      Seattle   NFC West      11.1
# 1         1664         NaN             NaN  New England   AFC East      11.3
# 2         1601         NaN             NaN    Green Bay  NFC North       9.7
# 3         1595         NaN             NaN       Denver   AFC West       9.6
# 4         1590         NaN             NaN       Dallas   NFC East       9.8
#
#   PROJ LOSES POINT DIFF MAKE PLAYOFFS WIN DIVISION 1st-Round Bye  \
# 0        4.9     +109.6           78%          60%           42%
# 1        4.7     +118.5           80%          62%           44%
# 2        6.2      +61.3           62%          49%           25%
# 3        6.4      +55.9           59%          44%           23%
# 4        6.2      +62.6           63%          47%           26%
#
#   Win Superbowl  Before Week  Year  PROJ_WINS2  PROJ_LOSSES2  REAL_WINS  \
# 0           15%            1  2015        11.1           4.9          0
# 1           14%            1  2015        11.3           4.7          0
# 2            7%            1  2015         9.7           6.3          0
# 3            6%            1  2015         9.6           6.4          0
# 4            6%            1  2015         9.8           6.2          0
#
#    REAL_LOSSES   CLEAN_NAME
# 0            0      Seattle
# 1            0  New England
# 2            0    Green Bay
# 3            0       Denver
# 4            0       Dallas

# %%
df_ab = df_a.loc[:, ["CLEAN_NAME", "ELO WITH QB", "ELO CHANGE", "CURRENT QB ADJ", "DIVISION", "PROJ_WINS2", "PROJ_LOSSES2", "REAL_WINS", "REAL_LOSSES", "POINT DIFF", "MAKE PLAYOFFS","WIN DIVISION", "1st-Round Bye", "Win Superbowl", "Before Week", "Year"]]

# %%
df_ab.head()
# Out:
#     CLEAN_NAME  ELO WITH QB  ELO CHANGE  CURRENT QB ADJ   DIVISION  \
# 0      Seattle         1678         NaN             NaN   NFC West
# 1  New England         1664         NaN             NaN   AFC East
# 2    Green Bay         1601         NaN             NaN  NFC North
# 3       Denver         1595         NaN             NaN   AFC West
# 4       Dallas         1590         NaN             NaN   NFC East
#
#    PROJ_WINS2  PROJ_LOSSES2  REAL_WINS  REAL_LOSSES POINT DIFF MAKE PLAYOFFS  \
# 0        11.1           4.9          0            0     +109.6           78%
# 1        11.3           4.7          0            0     +118.5           80%
# 2         9.7           6.3          0            0      +61.3           62%
# 3         9.6           6.4          0            0      +55.9           59%
# 4         9.8           6.2          0            0      +62.6           63%
#
#   WIN DIVISION 1st-Round Bye Win Superbowl  Before Week  Year
# 0          60%           42%           15%            1  2015
# 1          62%           44%           14%            1  2015
# 2          49%           25%            7%            1  2015
# 3          44%           23%            6%            1  2015
# 4          47%           26%            6%            1  2015

# %%
df_ab.tail()
# Out:
#      CLEAN_NAME  ELO WITH QB  ELO CHANGE  CURRENT QB ADJ   DIVISION  \
# 3615      Lions         1406       -24.0             NaN  NFC North
# 3616     Giants         1367        14.0             NaN   NFC East
# 3617    Cowboys         1329        -3.0           -13.0   NFC East
# 3618    Jaguars         1298        -8.0           -91.0  AFC South
# 3619       Jets         1295       -17.0             1.0   AFC East
#
#       PROJ_WINS2  PROJ_LOSSES2  REAL_WINS  REAL_LOSSES POINT DIFF  \
# 3615         6.0          10.0          3            5      -78.4
# 3616         4.0          12.0          2            7      -94.1
# 3617         4.0          12.0          2            7     -134.1
# 3618         2.0          14.0          1            7     -180.8
# 3619         2.0          14.0          0            9     -217.7
#
#      MAKE PLAYOFFS WIN DIVISION 1st-Round Bye Win Superbowl  Before Week  Year
# 3615            5%          <1%           <1%           <1%           10  2020
# 3616            7%           7%           <1%           <1%           10  2020
# 3617            6%           6%           <1%           <1%           10  2020
# 3618           <1%          <1%           <1%           <1%           10  2020
# 3619           <1%            —             —           <1%           10  2020

# %%
df_ab
# Out:
#        CLEAN_NAME  ELO WITH QB  ELO CHANGE  CURRENT QB ADJ   DIVISION  \
# 0         Seattle         1678         NaN             NaN   NFC West
# 1     New England         1664         NaN             NaN   AFC East
# 2       Green Bay         1601         NaN             NaN  NFC North
# 3          Denver         1595         NaN             NaN   AFC West
# 4          Dallas         1590         NaN             NaN   NFC East
# ...           ...          ...         ...             ...        ...
# 3615        Lions         1406       -24.0             NaN  NFC North
# 3616       Giants         1367        14.0             NaN   NFC East
# 3617      Cowboys         1329        -3.0           -13.0   NFC East
# 3618      Jaguars         1298        -8.0           -91.0  AFC South
# 3619         Jets         1295       -17.0             1.0   AFC East
#
#       PROJ_WINS2  PROJ_LOSSES2  REAL_WINS  REAL_LOSSES POINT DIFF  \
# 0           11.1           4.9          0            0     +109.6
# 1           11.3           4.7          0            0     +118.5
# 2            9.7           6.3          0            0      +61.3
# 3            9.6           6.4          0            0      +55.9
# 4            9.8           6.2          0            0      +62.6
# ...          ...           ...        ...          ...        ...
# 3615         6.0          10.0          3            5      -78.4
# 3616         4.0          12.0          2            7      -94.1
# 3617         4.0          12.0          2            7     -134.1
# 3618         2.0          14.0          1            7     -180.8
# 3619         2.0          14.0          0            9     -217.7
#
#      MAKE PLAYOFFS WIN DIVISION 1st-Round Bye Win Superbowl  Before Week  Year
# 0              78%          60%           42%           15%            1  2015
# 1              80%          62%           44%           14%            1  2015
# 2              62%          49%           25%            7%            1  2015
# 3              59%          44%           23%            6%            1  2015
# 4              63%          47%           26%            6%            1  2015
# ...            ...          ...           ...           ...          ...   ...
# 3615            5%          <1%           <1%           <1%           10  2020
# 3616            7%           7%           <1%           <1%           10  2020
# 3617            6%           6%           <1%           <1%           10  2020
# 3618           <1%          <1%           <1%           <1%           10  2020
# 3619           <1%            —             —           <1%           10  2020
#
# [3620 rows x 16 columns]

# %%
Teams = ["Arizona Cardinals",
"Atlanta Falcons",
"Baltimore Ravens",
"Buffalo Bills",
"Carolina Panthers",
"Chicago Bears",
"Cincinnati Bengals",
"Cleveland Browns",
"Dallas Cowboys",
"Denver Broncos",
"Detroit Lions",
"Green Bay Packers",
"Houston Texans",
"Indianapolis Colts",
"Jacksonville Jaguars",
"Kansas City Chiefs",
"San Diego Chargers",
"St. Louis Rams",
"Oakland Raiders",
"Miami Dolphins",
"Minnesota Vikings",
"New York Giants",
"New York Jets",
"New England Patriots",
"New Orleans Saints",
"Philadelphia Eagles",
"Pittsburgh Steelers",
"San Francisco 49ers",
"Seattle Seahawks",
"Tampa Bay Buccaneers",
"Tennessee Titans",
"Washington Redskins"]

# %%
def getNames(teamCol):
    dict_0 = {}
    for team in teamCol:
        if team in dict_0.keys():
            dict_0[team] += 1
        else:
            dict_0[team] = 1
    return dict_0

# %%
df_ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3620 entries, 0 to 3619
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CLEAN_NAME      3620 non-null   object
#  1   ELO WITH QB     3620 non-null   int64
#  2   ELO CHANGE      2799 non-null   float64
#  3   CURRENT QB ADJ  112 non-null    float64
#  4   DIVISION        3620 non-null   object
#  5   PROJ_WINS2      2866 non-null   float64
#  6   PROJ_LOSSES2    2866 non-null   float64
#  7   REAL_WINS       3620 non-null   int64
#  8   REAL_LOSSES     3620 non-null   int64
#  9   POINT DIFF      3232 non-null   object
#  10  MAKE PLAYOFFS   3620 non-null   object
#  11  WIN DIVISION    3620 non-null   object
#  12  1st-Round Bye   3620 non-null   object
#  13  Win Superbowl   3588 non-null   object
#  14  Before Week     3620 non-null   int64
#  15  Year            3620 non-null   int64
# dtypes: float64(4), int64(5), object(7)
# memory usage: 480.8+ KB

# %%
d = getNames(df_ab.CLEAN_NAME)

# %%
d
# Out:
# {'Seattle': 91,
#  'New England': 105,
#  'Green Bay': 86,
#  'Denver': 102,
#  'Dallas': 105,
#  'Indianapolis': 105,
#  'Baltimore': 105,
#  'Pittsburgh': 85,
#  'Philadelphia': 105,
#  'Arizona': 68,
#  'Cincinnati': 89,
#  'Kansas City': 105,
#  'Detroit': 82,
#  'Carolina': 102,
#  'Buffalo': 102,
#  'San Francisco': 102,
#  'San Diego': 42,
#  'Houston': 105,
#  'New Orleans': 105,
#  'Miami': 102,
#  'N.Y. Giants': 102,
#  'Minnesota': 86,
#  'St. Louis': 21,
#  'Atlanta': 102,
#  'N.Y. Jets': 102,
#  'Cleveland': 85,
#  'Chicago': 105,
#  'Oakland': 102,
#  'Tampa Bay': 102,
#  'Washington': 99,
#  'Jacksonville': 102,
#  'Tennessee': 102,
#  'Los Angeles': 21,
#  'Seattle-1': 14,
#  'Arizona-1': 34,
#  'Washington-1': 13,
#  'Cincinnati-1': 13,
#  'L.A. Chargers': 63,
#  'L.A. Rams': 63,
#  'Pittsburgh-1': 17,
#  'Cleveland-1': 17,
#  'Minnesota-1': 16,
#  'Green Bay-1': 16,
#  'Detroit-1': 20,
#  'Chiefs': 10,
#  'Ravens': 10,
#  'Saints': 10,
#  '49ers': 10,
#  'Steelers': 10,
#  'Cowboys': 10,
#  'Packers': 10,
#  'Patriots': 10,
#  'Titans': 10,
#  'Eagles': 3,
#  'Seahawks': 10,
#  'Vikings': 10,
#  'Rams': 10,
#  'Buccaneers': 10,
#  'Bills': 10,
#  'Bears': 10,
#  'Colts': 10,
#  'Texans': 10,
#  'Falcons': 10,
#  'Browns': 10,
#  'Broncos': 10,
#  'Raiders': 10,
#  'Cardinals': 10,
#  'Chargers': 10,
#  'Jets': 10,
#  'Lions': 10,
#  'Dolphins': 10,
#  'Panthers': 10,
#  'Giants': 10,
#  'Bengals': 3,
#  'Jaguars': 10,
#  'Eagles-1': 7,
#  'Bengals-1': 7}

# %%
pat = re.compile("(\d+-\d+)(-\d+)?")

# %%
pat.search("1-2-1")
# Out:
# <re.Match object; span=(0, 5), match='1-2-1'>

# %%
def cleanName(name):
    regex = re.compile("(\d+-\d+)(-\d+)?")
    record = regex.search(name)
    if record != None:
        record = record[0]
        name = name.replace(record, "")
        return name
    else:
        return name

# %%
df_a = df_a.assign(CLEAN_NAME2 = lambda x : x.TEAM.apply(cleanName))

# %%
def realWins(name):
    regex = re.compile("(\d+-\d+)(-\d+)?")
    record = regex.search(name)
    if record != None:
        record = record[0]
        #record = record[1:]
        rec = record.split("-")
        wins = rec[0]
        losses = rec[1]
        return wins
    else:
        return 0

# %%
def realLss(name):
    regex = re.compile("(\d+-\d+)(-\d+)?")
    record = regex.search(name)
    if record != None:
        record = record[0]
        #record = record[1:]
        rec = record.split("-")
        wins = rec[0]
        losses = rec[1]
        return losses
    else:
        return 0

# %%
def realTies(name):
    regex = re.compile("(\d+-\d+)(-\d+)?")
    record = regex.search(name)
    if record != None:
        record = record[0]
        #record = record[1:]
        rec = record.split("-")
        wins = rec[0]
        losses = rec[1]
        if len(rec) > 2:
            ties = rec[2]
            return ties
        else:
            return 0
    else:
        return 0

# %%
df_a.columns
# Out:
# Index(['ELO WITH QB', 'ELO CHANGE', 'CURRENT QB ADJ', 'TEAM', 'DIVISION',
#        'PROJ WINS', 'PROJ LOSES', 'POINT DIFF', 'MAKE PLAYOFFS',
#        'WIN DIVISION', '1st-Round Bye', 'Win Superbowl', 'Before Week', 'Year',
#        'PROJ_WINS2', 'PROJ_LOSSES2', 'REAL_WINS', 'REAL_LOSSES', 'CLEAN_NAME',
#        'CLEAN_NAME2'],
#       dtype='object')

# %%
df_a = df_a.assign(REAL_WINS2 = lambda x: x.TEAM.apply(realWins))

# %%
df_a = df_a.assign(REAL_LOSSES2 = lambda x: x.TEAM.apply(realLss))

# %%
df_a = df_a.assign(REAL_TIES = lambda x: x.TEAM.apply(realTies))

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3620 entries, 0 to 3619
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ELO WITH QB     3620 non-null   int64
#  1   ELO CHANGE      2799 non-null   float64
#  2   CURRENT QB ADJ  112 non-null    float64
#  3   TEAM            3620 non-null   object
#  4   DIVISION        3620 non-null   object
#  5   PROJ WINS       3264 non-null   object
#  6   PROJ LOSES      2368 non-null   object
#  7   POINT DIFF      3232 non-null   object
#  8   MAKE PLAYOFFS   3620 non-null   object
#  9   WIN DIVISION    3620 non-null   object
#  10  1st-Round Bye   3620 non-null   object
#  11  Win Superbowl   3588 non-null   object
#  12  Before Week     3620 non-null   int64
#  13  Year            3620 non-null   int64
#  14  PROJ_WINS2      2866 non-null   float64
#  15  PROJ_LOSSES2    2866 non-null   float64
#  16  REAL_WINS       3620 non-null   int64
#  17  REAL_LOSSES     3620 non-null   int64
#  18  CLEAN_NAME      3620 non-null   object
#  19  CLEAN_NAME2     3620 non-null   object
#  20  REAL_WINS2      3620 non-null   object
#  21  REAL_LOSSES2    3620 non-null   object
#  22  REAL_TIES       3620 non-null   object
# dtypes: float64(4), int64(5), object(14)
# memory usage: 678.8+ KB

# %%
def cleanWins(record):
    if("." in str(record)):
        return record
    elif (type(record) != float) and ("-" not in record):
        return record
    elif (type(record) != float) and ("-" in record):
        regx = re.compile("\d+-")
        wins = regx.search(record)
        if wins != None:
            wins = wins[0][:-1]
        #losses = regx.search(record)[1]
            return wins

# %%
def cleanLs(record):
    if("." in str(record)):
        record = float(record)
        record = 16 - record
        return record
    elif (type(record) != float) and ("-" not in record):
        return record
    elif (type(record) != float) and ("-" in record):
        regx = re.compile("-\d+")
        wins = regx.search(record)
        if wins != None:
            wins = wins[0][1:]
        #losses = regx.search(record)[1]
            return wins

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3620 entries, 0 to 3619
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ELO WITH QB     3620 non-null   int64
#  1   ELO CHANGE      2799 non-null   float64
#  2   CURRENT QB ADJ  112 non-null    float64
#  3   TEAM            3620 non-null   object
#  4   DIVISION        3620 non-null   object
#  5   PROJ WINS       3264 non-null   object
#  6   PROJ LOSES      2368 non-null   object
#  7   POINT DIFF      3232 non-null   object
#  8   MAKE PLAYOFFS   3620 non-null   object
#  9   WIN DIVISION    3620 non-null   object
#  10  1st-Round Bye   3620 non-null   object
#  11  Win Superbowl   3588 non-null   object
#  12  Before Week     3620 non-null   int64
#  13  Year            3620 non-null   int64
#  14  PROJ_WINS2      2866 non-null   float64
#  15  PROJ_LOSSES2    2866 non-null   float64
#  16  REAL_WINS       3620 non-null   int64
#  17  REAL_LOSSES     3620 non-null   int64
#  18  CLEAN_NAME      3620 non-null   object
#  19  CLEAN_NAME2     3620 non-null   object
#  20  REAL_WINS2      3620 non-null   object
#  21  REAL_LOSSES2    3620 non-null   object
#  22  REAL_TIES       3620 non-null   object
# dtypes: float64(4), int64(5), object(14)
# memory usage: 678.8+ KB

# %%
df_a =df_a.assign(PROJ_WINS3 = lambda x: x["PROJ WINS"].apply(cleanWins))

# %%
df_a = df_a.assign(PROJ_LOSS3 = lambda x: x["PROJ WINS"].apply(cleanLs))

# %%
df_a.to_csv("cleanestELO.csv", index=False)

# %% [markdown]
# # Step 3

# %%
df_h = pd.read_csv("cleanestELO.csv", header=0)

# %%
df_h.head()
# Out:
#    ELO WITH QB  ELO CHANGE  CURRENT QB ADJ         TEAM   DIVISION PROJ WINS  \
# 0         1678         NaN             NaN      Seattle   NFC West      11.1
# 1         1664         NaN             NaN  New England   AFC East      11.3
# 2         1601         NaN             NaN    Green Bay  NFC North       9.7
# 3         1595         NaN             NaN       Denver   AFC West       9.6
# 4         1590         NaN             NaN       Dallas   NFC East       9.8
#
#   PROJ LOSES POINT DIFF MAKE PLAYOFFS WIN DIVISION  ... PROJ_LOSSES2  \
# 0        4.9     +109.6           78%          60%  ...          4.9
# 1        4.7     +118.5           80%          62%  ...          4.7
# 2        6.2      +61.3           62%          49%  ...          6.3
# 3        6.4      +55.9           59%          44%  ...          6.4
# 4        6.2      +62.6           63%          47%  ...          6.2
#
#   REAL_WINS  REAL_LOSSES   CLEAN_NAME  CLEAN_NAME2  REAL_WINS2  REAL_LOSSES2  \
# 0         0            0      Seattle      Seattle           0             0
# 1         0            0  New England  New England           0             0
# 2         0            0    Green Bay    Green Bay           0             0
# 3         0            0       Denver       Denver           0             0
# 4         0            0       Dallas       Dallas           0             0
#
#    REAL_TIES PROJ_WINS3         PROJ_LOSS3
# 0          0       11.1                4.9
# 1          0       11.3  4.699999999999999
# 2          0        9.7  6.300000000000001
# 3          0        9.6                6.4
# 4          0        9.8  6.199999999999999
#
# [5 rows x 25 columns]

# %%
right_cols = list(df_h.columns[-6:])

# %%
left_cols = list(df_h.columns[:14])

# %%
for x in right_cols:
    left_cols.append(x)

# %%
left_cols
# Out:
# ['ELO WITH QB',
#  'ELO CHANGE',
#  'CURRENT QB ADJ',
#  'TEAM',
#  'DIVISION',
#  'PROJ WINS',
#  'PROJ LOSES',
#  'POINT DIFF',
#  'MAKE PLAYOFFS',
#  'WIN DIVISION',
#  '1st-Round Bye',
#  'Win Superbowl',
#  'Before Week',
#  'Year',
#  'CLEAN_NAME2',
#  'REAL_WINS2',
#  'REAL_LOSSES2',
#  'REAL_TIES',
#  'PROJ_WINS3',
#  'PROJ_LOSS3']

# %%
left_cols.remove("TEAM")

# %%
left_cols
# Out:
# ['ELO WITH QB',
#  'ELO CHANGE',
#  'CURRENT QB ADJ',
#  'DIVISION',
#  'PROJ WINS',
#  'PROJ LOSES',
#  'POINT DIFF',
#  'MAKE PLAYOFFS',
#  'WIN DIVISION',
#  '1st-Round Bye',
#  'Win Superbowl',
#  'Before Week',
#  'Year',
#  'CLEAN_NAME2',
#  'REAL_WINS2',
#  'REAL_LOSSES2',
#  'REAL_TIES',
#  'PROJ_WINS3',
#  'PROJ_LOSS3']

# %%
df_h2 = df_h.loc[:, left_cols]

# %%
df_h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3620 entries, 0 to 3619
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ELO WITH QB     3620 non-null   int64
#  1   ELO CHANGE      2799 non-null   float64
#  2   CURRENT QB ADJ  112 non-null    float64
#  3   TEAM            3620 non-null   object
#  4   DIVISION        3620 non-null   object
#  5   PROJ WINS       3264 non-null   object
#  6   PROJ LOSES      2368 non-null   object
#  7   POINT DIFF      3232 non-null   object
#  8   MAKE PLAYOFFS   3620 non-null   object
#  9   WIN DIVISION    3620 non-null   object
#  10  1st-Round Bye   3620 non-null   object
#  11  Win Superbowl   3588 non-null   object
#  12  Before Week     3620 non-null   int64
#  13  Year            3620 non-null   int64
#  14  PROJ_WINS2      2866 non-null   float64
#  15  PROJ_LOSSES2    2866 non-null   float64
#  16  REAL_WINS       3620 non-null   int64
#  17  REAL_LOSSES     3620 non-null   int64
#  18  CLEAN_NAME      3620 non-null   object
#  19  CLEAN_NAME2     3620 non-null   object
#  20  REAL_WINS2      3620 non-null   int64
#  21  REAL_LOSSES2    3620 non-null   int64
#  22  REAL_TIES       3620 non-null   int64
#  23  PROJ_WINS3      3264 non-null   object
#  24  PROJ_LOSS3      3264 non-null   object
# dtypes: float64(4), int64(8), object(13)
# memory usage: 707.2+ KB

# %%
df_h2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3620 entries, 0 to 3619
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ELO WITH QB     3620 non-null   int64
#  1   ELO CHANGE      2799 non-null   float64
#  2   CURRENT QB ADJ  112 non-null    float64
#  3   DIVISION        3620 non-null   object
#  4   PROJ WINS       3264 non-null   object
#  5   PROJ LOSES      2368 non-null   object
#  6   POINT DIFF      3232 non-null   object
#  7   MAKE PLAYOFFS   3620 non-null   object
#  8   WIN DIVISION    3620 non-null   object
#  9   1st-Round Bye   3620 non-null   object
#  10  Win Superbowl   3588 non-null   object
#  11  Before Week     3620 non-null   int64
#  12  Year            3620 non-null   int64
#  13  CLEAN_NAME2     3620 non-null   object
#  14  REAL_WINS2      3620 non-null   int64
#  15  REAL_LOSSES2    3620 non-null   int64
#  16  REAL_TIES       3620 non-null   int64
#  17  PROJ_WINS3      3264 non-null   object
#  18  PROJ_LOSS3      3264 non-null   object
# dtypes: float64(2), int64(6), object(11)
# memory usage: 537.5+ KB

# %%
df_h2Dict = getNames(df_h2.CLEAN_NAME2)

# %%
df_h2Dict
# Out:
# {'Seattle': 105,
#  'New England': 105,
#  'Green Bay': 102,
#  'Denver': 102,
#  'Dallas': 105,
#  'Indianapolis': 105,
#  'Baltimore': 105,
#  'Pittsburgh': 102,
#  'Philadelphia': 105,
#  'Arizona': 102,
#  'Cincinnati': 102,
#  'Kansas City': 105,
#  'Detroit': 102,
#  'Carolina': 102,
#  'Buffalo': 102,
#  'San Francisco': 102,
#  'San Diego': 42,
#  'Houston': 105,
#  'New Orleans': 105,
#  'Miami': 102,
#  'N.Y. Giants': 102,
#  'Minnesota': 102,
#  'St. Louis': 21,
#  'Atlanta': 102,
#  'N.Y. Jets': 102,
#  'Cleveland': 102,
#  'Chicago': 105,
#  'Oakland': 102,
#  'Tampa Bay': 102,
#  'Washington': 112,
#  'Jacksonville': 102,
#  'Tennessee': 102,
#  'Los Angeles': 21,
#  'L.A. Chargers': 63,
#  'L.A. Rams': 63,
#  'Chiefs': 10,
#  'Ravens': 10,
#  'Saints': 10,
#  '49ers': 10,
#  'Steelers': 10,
#  'Cowboys': 10,
#  'Packers': 10,
#  'Patriots': 10,
#  'Titans': 10,
#  'Eagles': 10,
#  'Seahawks': 10,
#  'Vikings': 10,
#  'Rams': 10,
#  'Buccaneers': 10,
#  'Bills': 10,
#  'Bears': 10,
#  'Colts': 10,
#  'Texans': 10,
#  'Falcons': 10,
#  'Browns': 10,
#  'Broncos': 10,
#  'Raiders': 10,
#  'Cardinals': 10,
#  'Chargers': 10,
#  'Jets': 10,
#  'Lions': 10,
#  'Dolphins': 10,
#  'Panthers': 10,
#  'Giants': 10,
#  'Bengals': 10,
#  'Jaguars': 10}

# %%
with open("dict.txt", "w") as file:
    file.write(str(df_h2Dict))

# %%
Teams
# Out:
# ['Arizona Cardinals',
#  'Atlanta Falcons',
#  'Baltimore Ravens',
#  'Buffalo Bills',
#  'Carolina Panthers',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Houston Texans',
#  'Indianapolis Colts',
#  'Jacksonville Jaguars',
#  'Kansas City Chiefs',
#  'San Diego Chargers',
#  'St. Louis Rams',
#  'Oakland Raiders',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New York Giants',
#  'New York Jets',
#  'New England Patriots',
#  'New Orleans Saints',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'Tampa Bay Buccaneers',
#  'Tennessee Titans',
#  'Washington Redskins']

# %%
parser = {
    "Seattle": "Seattle Seahawks",
    "Seahawks": "Seattle Seahawks",
    "New England": 'New England Patriots',
    'Patriots': 'New England Patriots',
    "Green Bay": 'Green Bay Packers',
    "Packers": 'Green Bay Packers',
    'Denver': 'Denver Broncos',
    "Broncos": 'Denver Broncos',
    "Dallas": 'Dallas Cowboys',
    "Cowboys": 'Dallas Cowboys',
    'Indianapolis': 'Indianapolis Colts',
    "Colts": 'Indianapolis Colts',
    'Baltimore': 'Baltimore Ravens',
    "Ravens": 'Baltimore Ravens',
    'Pittsburgh': 'Pittsburgh Steelers',
    "Steelers": 'Pittsburgh Steelers',
    'Philadelphia': 'Philadelphia Eagles',
    'Eagles': 'Philadelphia Eagles',
    'Arizona': 'Arizona Cardinals',
    "Cardinals": 'Arizona Cardinals',
    'Cincinnati': 'Cincinnati Bengals',
    'Bengals': 'Cincinnati Bengals',
    'Kansas City': 'Kansas City Chiefs',
    "Chiefs": 'Kansas City Chiefs',
    'Detroit': "Detroit Lions",
    "Lions": "Detroit Lions",
    'Carolina': 'Carolina Panthers',
    "Panthers": 'Carolina Panthers',
    'Buffalo': "Buffalo Bills",
    "Bills": "Buffalo Bills",
    'San Francisco': 'San Francisco 49ers',
    "49ers": 'San Francisco 49ers',
    'Houston': 'Houston Texans',
    "Texans": 'Houston Texans',
    'New Orleans': 'New Orleans Saints',
    "Saints": 'New Orleans Saints',
    'Miami': 'Miami Dolphins',
    "Dolphins": 'Miami Dolphins',
    'N.Y. Giants':'New York Giants',
    "Giants": 'New York Giants', 
    'Minnesota': 'Minnesota Vikings',
    "Vikings": 'Minnesota Vikings', 
    'San Diego': "San Diego Chargers",
    'L.A. Chargers': "San Diego Chargers",
    'Chargers': "San Diego Chargers",
    'St. Louis': "St. Louis Rams",
    'Los Angeles': "St. Louis Rams",
    'L.A. Rams': "St. Louis Rams",
    'Rams': "St. Louis Rams",
    'Atlanta': "Atlanta Falcons",
    'Falcons': "Atlanta Falcons",
    'N.Y. Jets': 'New York Jets',
    'Jets': 'New York Jets', 
    'Cleveland': 'Cleveland Browns',
    'Browns': 'Cleveland Browns',
    'Chicago': 'Chicago Bears',
    'Bears': 'Chicago Bears',
    'Oakland': 'Oakland Raiders',
    'Raiders': 'Oakland Raiders',
    'Tampa Bay': 'Tampa Bay Buccaneers',
    'Buccaneers': 'Tampa Bay Buccaneers',
    'Washington': 'Washington Redskins',
    'Jacksonville': 'Jacksonville Jaguars',
    'Jaguars': 'Jacksonville Jaguars',
    'Tennessee': 'Tennessee Titans',
    'Titans': 'Tennessee Titans',
}

# %%
def cleanNamez(name):
    return parser[name]

# %%
df_h2.head()
# Out:
#    ELO WITH QB  ELO CHANGE  CURRENT QB ADJ   DIVISION PROJ WINS PROJ LOSES  \
# 0         1678         NaN             NaN   NFC West      11.1        4.9
# 1         1664         NaN             NaN   AFC East      11.3        4.7
# 2         1601         NaN             NaN  NFC North       9.7        6.2
# 3         1595         NaN             NaN   AFC West       9.6        6.4
# 4         1590         NaN             NaN   NFC East       9.8        6.2
#
#   POINT DIFF MAKE PLAYOFFS WIN DIVISION 1st-Round Bye Win Superbowl  \
# 0     +109.6           78%          60%           42%           15%
# 1     +118.5           80%          62%           44%           14%
# 2      +61.3           62%          49%           25%            7%
# 3      +55.9           59%          44%           23%            6%
# 4      +62.6           63%          47%           26%            6%
#
#    Before Week  Year  CLEAN_NAME2  REAL_WINS2  REAL_LOSSES2  REAL_TIES  \
# 0            1  2015      Seattle           0             0          0
# 1            1  2015  New England           0             0          0
# 2            1  2015    Green Bay           0             0          0
# 3            1  2015       Denver           0             0          0
# 4            1  2015       Dallas           0             0          0
#
#   PROJ_WINS3         PROJ_LOSS3
# 0       11.1                4.9
# 1       11.3  4.699999999999999
# 2        9.7  6.300000000000001
# 3        9.6                6.4
# 4        9.8  6.199999999999999

# %%
df_h2 = df_h2.assign(FinalName = lambda x: x.CLEAN_NAME2.apply(cleanNamez))

# %%
df_h3 = df_h2.drop("CLEAN_NAME2", axis=1)

# %%
df_h3.columns
# Out:
# Index(['ELO WITH QB', 'ELO CHANGE', 'CURRENT QB ADJ', 'DIVISION', 'PROJ WINS',
#        'PROJ LOSES', 'POINT DIFF', 'MAKE PLAYOFFS', 'WIN DIVISION',
#        '1st-Round Bye', 'Win Superbowl', 'Before Week', 'Year', 'REAL_WINS2',
#        'REAL_LOSSES2', 'REAL_TIES', 'PROJ_WINS3', 'PROJ_LOSS3', 'FinalName'],
#       dtype='object')

# %%
df_h3.to_csv("cleanestELO.csv", index=False)

# %%
df_h3.head()
# Out:
#    ELO WITH QB  ELO CHANGE  CURRENT QB ADJ   DIVISION PROJ WINS PROJ LOSES  \
# 0         1678         NaN             NaN   NFC West      11.1        4.9
# 1         1664         NaN             NaN   AFC East      11.3        4.7
# 2         1601         NaN             NaN  NFC North       9.7        6.2
# 3         1595         NaN             NaN   AFC West       9.6        6.4
# 4         1590         NaN             NaN   NFC East       9.8        6.2
#
#   POINT DIFF MAKE PLAYOFFS WIN DIVISION 1st-Round Bye Win Superbowl  \
# 0     +109.6           78%          60%           42%           15%
# 1     +118.5           80%          62%           44%           14%
# 2      +61.3           62%          49%           25%            7%
# 3      +55.9           59%          44%           23%            6%
# 4      +62.6           63%          47%           26%            6%
#
#    Before Week  Year  REAL_WINS2  REAL_LOSSES2  REAL_TIES PROJ_WINS3  \
# 0            1  2015           0             0          0       11.1
# 1            1  2015           0             0          0       11.3
# 2            1  2015           0             0          0        9.7
# 3            1  2015           0             0          0        9.6
# 4            1  2015           0             0          0        9.8
#
#           PROJ_LOSS3             FinalName
# 0                4.9      Seattle Seahawks
# 1  4.699999999999999  New England Patriots
# 2  6.300000000000001     Green Bay Packers
# 3                6.4        Denver Broncos
# 4  6.199999999999999        Dallas Cowboys

# %%
def cleanPercent(s):
    s = str(s)
    s = s.strip()
    if s.startswith(">99"):
        s = "99"
    elif s.startswith("<1"):
        s = "1"
    if (">" not in s) and ("%" in s):
        num = s.replace("%", "")
        num = float(num) / 100
        return num
    elif ">" in s:
        num = s.replace(">", "")
        num = s.replace("%", "")
        num = float(num) / 100
        return num
    elif "<" in s:
        num = s.replace("<", "")
        num = float(num) / 100
        return num
    else:
        return 0.003

# %%
df_h3 = df_h3.assign(Playoffs_Prob = lambda x: x["MAKE PLAYOFFS"].apply(cleanPercent))

# %%
df_h3 = df_h3.assign(Division_Prob = lambda x: x["WIN DIVISION"].apply(cleanPercent))

# %%
df_h3 = df_h3.assign(Bye_Prob = lambda x: x["1st-Round Bye"].apply(cleanPercent))

# %%
df_h3 = df_h3.assign(SB_Prob = lambda x: x["Win Superbowl"].apply(cleanPercent))

# %%
df_h3.columns
# Out:
# Index(['ELO WITH QB', 'ELO CHANGE', 'CURRENT QB ADJ', 'DIVISION', 'PROJ WINS',
#        'PROJ LOSES', 'POINT DIFF', 'MAKE PLAYOFFS', 'WIN DIVISION',
#        '1st-Round Bye', 'Win Superbowl', 'Before Week', 'Year', 'REAL_WINS2',
#        'REAL_LOSSES2', 'REAL_TIES', 'PROJ_WINS3', 'PROJ_LOSS3', 'FinalName',
#        'Playoffs_Prob', 'Division_Prob', 'Bye_Prob', 'SB_Prob'],
#       dtype='object')

# %%
">99".replace(">", "")
# Out:
# '99'

# %%
def cleanPoints(pts):
    pts = str(pts)
    if "+" in pts:
        pts = pts.replace("+", "")
        pts = float(pts)
        return pts
    elif "-" in pts:
        pts = pts.replace("-", "")
        pts = float(pts)
        return -pts
    else:
        return 0.00

# %%
df_h3 = df_h3.assign(SB_Prob = lambda x: x['POINT DIFF'].apply(cleanPoints))

# %%
df_h3.columns
# Out:
# Index(['ELO WITH QB', 'ELO CHANGE', 'CURRENT QB ADJ', 'DIVISION', 'PROJ WINS',
#        'PROJ LOSES', 'POINT DIFF', 'MAKE PLAYOFFS', 'WIN DIVISION',
#        '1st-Round Bye', 'Win Superbowl', 'Before Week', 'Year', 'REAL_WINS2',
#        'REAL_LOSSES2', 'REAL_TIES', 'PROJ_WINS3', 'PROJ_LOSS3', 'FinalName',
#        'Playoffs_Prob', 'Division_Prob', 'Bye_Prob', 'SB_Prob'],
#       dtype='object')

# %%
df_h3.head()
# Out:
#    ELO WITH QB  ELO CHANGE  CURRENT QB ADJ   DIVISION PROJ WINS PROJ LOSES  \
# 0         1678         NaN             NaN   NFC West      11.1        4.9
# 1         1664         NaN             NaN   AFC East      11.3        4.7
# 2         1601         NaN             NaN  NFC North       9.7        6.2
# 3         1595         NaN             NaN   AFC West       9.6        6.4
# 4         1590         NaN             NaN   NFC East       9.8        6.2
#
#   POINT DIFF MAKE PLAYOFFS WIN DIVISION 1st-Round Bye  ... REAL_WINS2  \
# 0     +109.6           78%          60%           42%  ...          0
# 1     +118.5           80%          62%           44%  ...          0
# 2      +61.3           62%          49%           25%  ...          0
# 3      +55.9           59%          44%           23%  ...          0
# 4      +62.6           63%          47%           26%  ...          0
#
#    REAL_LOSSES2  REAL_TIES  PROJ_WINS3         PROJ_LOSS3  \
# 0             0          0        11.1                4.9
# 1             0          0        11.3  4.699999999999999
# 2             0          0         9.7  6.300000000000001
# 3             0          0         9.6                6.4
# 4             0          0         9.8  6.199999999999999
#
#               FinalName Playoffs_Prob Division_Prob Bye_Prob  SB_Prob
# 0      Seattle Seahawks          0.78          0.60     0.42    109.6
# 1  New England Patriots          0.80          0.62     0.44    118.5
# 2     Green Bay Packers          0.62          0.49     0.25     61.3
# 3        Denver Broncos          0.59          0.44     0.23     55.9
# 4        Dallas Cowboys          0.63          0.47     0.26     62.6
#
# [5 rows x 23 columns]

# %%
final_five_df = df_h3.loc[:, ["FinalName", "DIVISION", "ELO WITH QB", "ELO CHANGE", "CURRENT QB ADJ",
             'Playoffs_Prob', 'Division_Prob', 'Bye_Prob', 'SB_Prob','PROJ_WINS3', 'PROJ_LOSS3',
              'REAL_WINS2','REAL_LOSSES2', 'REAL_TIES',
              'Before Week', 'Year']]

# %%
final_five_df.to_csv("ELO_cleaned.csv", index=False)
