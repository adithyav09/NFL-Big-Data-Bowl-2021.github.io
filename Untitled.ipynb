# %%
import pandas as pd
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

# %%
df1 = pd.read_csv('2015_through_2020_Results.csv')
dfFPI = pd.read_csv('2015-2020_FPI.csv')
# Out:
# /Users/adithyavenkatesh/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (0,2,5,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.head()
# Out:
#    Year Week  Day    Date    Time            Winner/tie Unnamed: 6  \
# 0  2015    1  Thu  10-Sep  8:40PM  New England Patriots        NaN
# 1  2015    1  Sun  13-Sep  1:00PM        St. Louis Rams        NaN
# 2  2015    1  Sun  13-Sep  1:00PM     Green Bay Packers          @
# 3  2015    1  Sun  13-Sep  1:02PM        Miami Dolphins          @
# 4  2015    1  Sun  13-Sep  1:02PM    Kansas City Chiefs          @
#
#              Loser/tie Unnamed: 8  PtsW  PtsL   YdsW  TOW   YdsL  TOL
# 0  Pittsburgh Steelers   boxscore  28.0  21.0  361.0  0.0  464.0  1.0
# 1     Seattle Seahawks   boxscore  34.0  31.0  352.0  3.0  343.0  1.0
# 2        Chicago Bears   boxscore  31.0  23.0  322.0  0.0  402.0  1.0
# 3  Washington Redskins   boxscore  17.0  10.0  256.0  1.0  349.0  2.0
# 4       Houston Texans   boxscore  27.0  20.0  330.0  0.0  396.0  2.0

# %%
dfFPI = dfFPI.dropna(how = 'all')

# %%
dfFPI.head()
# Out:
#                    TEAM   Year    W-L-T  Power Index FPI  Power Index RK  \
# 0      Seattle Seahawks  2015.0  11-7-0              8.8             1.0
# 1     Arizona Cardinals  2015.0  14-4-0              8.3             2.0
# 2     Carolina Panthers  2015.0  17-2-0              7.9             3.0
# 3  New England Patriots  2015.0  13-5-0              7.2             4.0
# 4   Pittsburgh Steelers  2015.0  11-7-0              7.1             5.0
#
#   Power Index TREND  Power Index OFF  Power Index DEF  Power Index ST  \
# 0                --              6.0              3.0            -0.3
# 1                --              6.0              2.6            -0.4
# 2                --              3.5              4.8            -0.4
# 3                --              5.6              1.2             0.4
# 4                --              4.9              1.9             0.3
#
#    Ranks SOS Ranks REM SOS  Ranks AVGWP
# 0        6.0            --          6.0
# 1       17.0            --          3.0
# 2       28.0            --          1.0
# 3       18.0            --          2.0
# 4        5.0            --          9.0

# %%
df1
# Out:
#    Year Week  Day    Date    Time            Winner/tie Unnamed: 6  \
# 0  2015    1  Thu  10-Sep  8:40PM  New England Patriots        NaN
# 1  2015    1  Sun  13-Sep  1:00PM        St. Louis Rams        NaN
# 2  2015    1  Sun  13-Sep  1:00PM     Green Bay Packers          @
# 3  2015    1  Sun  13-Sep  1:02PM        Miami Dolphins          @
# 4  2015    1  Sun  13-Sep  1:02PM    Kansas City Chiefs          @
#
#              Loser/tie Unnamed: 8  PtsW  PtsL   YdsW  TOW   YdsL  TOL
# 0  Pittsburgh Steelers   boxscore  28.0  21.0  361.0  0.0  464.0  1.0
# 1     Seattle Seahawks   boxscore  34.0  31.0  352.0  3.0  343.0  1.0
# 2        Chicago Bears   boxscore  31.0  23.0  322.0  0.0  402.0  1.0
# 3  Washington Redskins   boxscore  17.0  10.0  256.0  1.0  349.0  2.0
# 4       Houston Texans   boxscore  27.0  20.0  330.0  0.0  396.0  2.0

# %%
df1.join(dfFPI)
df1.dtypes
# Out:
# Year            int64
# Week           object
# Day            object
# Date           object
# Time           object
# Winner/tie     object
# Unnamed: 6     object
# Loser/tie      object
# Unnamed: 8     object
# PtsW          float64
# PtsL          float64
# YdsW          float64
# TOW           float64
# YdsL          float64
# TOL           float64
# dtype: object

# %%
# pd.merge(df1, dfFPI, left_on = ['Year', 'Winner/tie'], right_on = ['Year', 'Team'])
df1.columns
# Out:
# Index(['Year', 'Week', 'Day', 'Date', 'Time', 'Winner/tie', 'Unnamed: 6',
#        'Loser/tie', 'Unnamed: 8', 'PtsW', 'PtsL', 'YdsW', 'TOW', 'YdsL',
#        'TOL'],
#       dtype='object')

# %%
dfFPI = dfFPI.rename({'Year' :'Year '})
dfFPI.columns
# Out:
# Index(['TEAM', 'Year ', 'W-L-T', 'Power Index FPI', 'Power Index RK',
#        'Power Index TREND', 'Power Index OFF', 'Power Index DEF',
#        'Power Index ST', 'Ranks SOS', 'Ranks REM SOS', 'Ranks AVGWP'],
#       dtype='object')

# %%
mergedDF = pd.merge(df1, dfFPI, left_on = ['Year', 'Winner/tie'], right_on = ['Year ', 'TEAM'], suffixes = ('', '_Winning Team'))

# %%
mergedDF.loc[:1476, :]
# Out:
#       Year Week  Day    Date    Time            Winner/tie Unnamed: 6  \
# 0     2015    1  Thu  10-Sep  8:40PM  New England Patriots        NaN
# 1     2015    2  Sun  20-Sep  1:02PM  New England Patriots          @
# 2     2015    3  Sun  27-Sep  1:06PM  New England Patriots        NaN
# 3     2015    5  Sun  11-Oct  4:25PM  New England Patriots          @
# 4     2015    6  Sun  18-Oct  8:30PM  New England Patriots          @
# ...    ...  ...  ...     ...     ...                   ...        ...
# 1472  2020   12  Sun  29-Nov  1:00PM      Cleveland Browns          @
# 1473  2020   13  Sun   6-Dec  1:00PM      Cleveland Browns          @
# 1474  2020   15  Sun  20-Dec  1:00PM      Cleveland Browns          @
# 1475  2020   16  Sun  27-Dec  1:00PM      Cleveland Browns          @
# 1476  2020    2  Sun  20-Sep  1:00PM   San Francisco 49ers          @
#
#                  Loser/tie Unnamed: 8  PtsW  ...   W-L-T  Power Index FPI  \
# 0      Pittsburgh Steelers   boxscore  28.0  ...  13-5-0              7.2
# 1            Buffalo Bills   boxscore  40.0  ...  13-5-0              7.2
# 2     Jacksonville Jaguars   boxscore  51.0  ...  13-5-0              7.2
# 3           Dallas Cowboys   boxscore  30.0  ...  13-5-0              7.2
# 4       Indianapolis Colts   boxscore  34.0  ...  13-5-0              7.2
# ...                    ...        ...   ...  ...     ...              ...
# 1472  Jacksonville Jaguars    preview   NaN  ...   5-3-0             -1.5
# 1473      Tennessee Titans    preview   NaN  ...   5-3-0             -1.5
# 1474       New York Giants    preview   NaN  ...   5-3-0             -1.5
# 1475         New York Jets    preview   NaN  ...   5-3-0             -1.5
# 1476         New York Jets   boxscore  31.0  ...   4-5-0              3.7
#
#       Power Index RK  Power Index TREND  Power Index OFF Power Index DEF  \
# 0                4.0                 --              5.6             1.2
# 1                4.0                 --              5.6             1.2
# 2                4.0                 --              5.6             1.2
# 3                4.0                 --              5.6             1.2
# 4                4.0                 --              5.6             1.2
# ...              ...                ...              ...             ...
# 1472            21.0                 --              0.5            -1.9
# 1473            21.0                 --              0.5            -1.9
# 1474            21.0                 --              0.5            -1.9
# 1475            21.0                 --              0.5            -1.9
# 1476             9.0                  4              2.3             1.2
#
#       Power Index ST Ranks SOS  Ranks REM SOS  Ranks AVGWP
# 0                0.4      18.0             --          2.0
# 1                0.4      18.0             --          2.0
# 2                0.4      18.0             --          2.0
# 3                0.4      18.0             --          2.0
# 4                0.4      18.0             --          2.0
# ...              ...       ...            ...          ...
# 1472            -0.1      24.0             30         19.0
# 1473            -0.1      24.0             30         19.0
# 1474            -0.1      24.0             30         19.0
# 1475            -0.1      24.0             30         19.0
# 1476             0.2      21.0              9         15.0
#
# [1477 rows x 27 columns]
