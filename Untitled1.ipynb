# %%
import pandas as pd

# %%
df = pd.read_csv('scoresAndStats.csv')
df.head()
# Out:
#    Year Week  Day    Date    Time           Winner/tie Unnamed: 6  \
# 0  2015   17  Sun   3-Jan  1:02PM        Detroit Lions          @
# 1  2015    6  Sun  18-Oct  1:02PM        Detroit Lions        NaN
# 2  2015   14  Sun  13-Dec  1:02PM  Washington Redskins          @
# 3  2015   11  Sun  22-Nov  1:02PM       Denver Broncos          @
# 4  2015   13  Sun   6-Dec  1:02PM  San Francisco 49ers          @
#
#        Loser/tie Unnamed: 8  PtsW  ...  W-L-T_Losing Team  \
# 0  Chicago Bears   boxscore    24  ...             6-10-0
# 1  Chicago Bears   boxscore    37  ...             6-10-0
# 2  Chicago Bears   boxscore    24  ...             6-10-0
# 3  Chicago Bears   boxscore    17  ...             6-10-0
# 4  Chicago Bears   boxscore    26  ...             6-10-0
#
#    Power Index FPI_Losing Team  Power Index RK_Losing Team  \
# 0                           -3                          22
# 1                           -3                          22
# ...

# %%
df.Year = df.Year.astype(int)
df.Year = df.Year.astype(str)

# %%
df['datetime'] = pd.to_datetime(df['Year'] + '-' + df['Date'])
df['datetime']
# Out:
# 0      2015-01-03
# 1      2015-10-18
# 2      2015-12-13
# 3      2015-11-22
# 4      2015-12-06
#           ...
# 1446   2020-10-04
# 1447   2020-09-13
# 1448   2020-09-20
# 1449   2020-09-27
# 1450   2020-10-04
# Name: datetime, Length: 1451, dtype: datetime64[ns]

# %%
df.to_csv('barRaceData.csv')
